# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarshan-23/Mental-fitness/blob/main/Mental_fitness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# Importing dataset
#
# ---
#
#
#
# ---

# %%
df1=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/prevalence-by-mental-and-substance-use-disorder.csv")
df2=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/mental-and-substance-use-as-share-of-disease.csv")

# %%
df1.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
df2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %%
data=pd.merge(df1,df2)
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %% [markdown]
# Data Cleaning

# %%
data.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               690
# Year                                                                                                 0
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                             0
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)                         0
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)                      0
# ...

# %%
data.drop("Code",axis=1,inplace=True)

# %%
data.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %% [markdown]
# **Data Visualisation**

# %%
data.set_axis(['Country','Year','Schizophrenia','Bipolar','Eating disorder','Anxiety','Drug use','Depressive disorder','Alcohol use','Men-fitness'],axis='columns',inplace=True)
data.head()
# Out:
# <ipython-input-11-479e05c174b2>:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   data.set_axis(['Country','Year','Schizophrenia','Bipolar','Eating disorder','Anxiety','Drug use','Depressive disorder','Alcohol use','Men-fitness'],axis='columns',inplace=True)
#        Country  Year  Schizophrenia   Bipolar  Eating disorder   Anxiety  \
# 0  Afghanistan  1990       0.228979  0.721207         0.131001  4.835127
# 1  Afghanistan  1991       0.228120  0.719952         0.126395  4.821765
# 2  Afghanistan  1992       0.227328  0.718418         0.121832  4.801434
# 3  Afghanistan  1993       0.226468  0.717452         0.117942  4.789363
# 4  Afghanistan  1994       0.225567  0.717012         0.114547  4.784923
#
#    Drug use  Depressive disorder  Alcohol use  Men-fitness
# 0  0.454202             5.125291     0.444036     1.696670
# ...

# %%
data.size,data.shape
# Out:
# (68400, (6840, 10))

# %%
data.shape
# Out:
# (6840, 10)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True,cmap='Greens')
plt.plot()
# Out:
# <ipython-input-14-42d3b685fd0f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap='Greens')
# []

# %%
sns.jointplot(data=data, x="Bipolar",y="Men-fitness",kind='reg',color='red')

# %%
sns.kdeplot(data=data, x="Eating disorder",y="Men-fitness")
# Out:
# <Axes: xlabel='Eating disorder', ylabel='Men-fitness'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              6840 non-null   object
#  1   Year                 6840 non-null   int64
#  2   Schizophrenia        6840 non-null   float64
#  3   Bipolar              6840 non-null   float64
#  4   Eating disorder      6840 non-null   float64
#  5   Anxiety              6840 non-null   float64
#  6   Drug use             6840 non-null   float64
#  7   Depressive disorder  6840 non-null   float64
#  8   Alcohol use          6840 non-null   float64
#  9   Men-fitness          6840 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 587.8+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           Country  Year  Schizophrenia   Bipolar  Eating disorder   Anxiety  \
# 0     Afghanistan  1990       0.228979  0.721207         0.131001  4.835127
# 1     Afghanistan  1991       0.228120  0.719952         0.126395  4.821765
# 2     Afghanistan  1992       0.227328  0.718418         0.121832  4.801434
# 3     Afghanistan  1993       0.226468  0.717452         0.117942  4.789363
# 4     Afghanistan  1994       0.225567  0.717012         0.114547  4.784923
# ...           ...   ...            ...       ...              ...       ...
# 6835     Zimbabwe  2015       0.209359  0.560882         0.099610  3.315701
# 6836     Zimbabwe  2016       0.209979  0.561768         0.100821  3.324230
# 6837     Zimbabwe  2017       0.210631  0.562612         0.101671  3.330569
# 6838     Zimbabwe  2018       0.211237  0.563283         0.102398  3.317500
# 6839     Zimbabwe  2019       0.211969  0.563820         0.102902  3.283934
#
# ...

# %%
fig = px.pie(data, values='Men-fitness', names='Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in data.columns:
    if data[i].dtype == 'object':
        data[i]=l.fit_transform(data[i])

# %%
X=data.drop('Men-fitness',axis=1)
Y=data['Men-fitness']

# %% [markdown]
# Splitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import *
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %% [markdown]
# **Linear Regression Model**
#
# ---

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
x_train_pred = reg.predict(x_train)
r2_score(y_train, x_train_pred)
# Out:
# 0.7413245790025275

# %%
x_test_pred = reg.predict(x_test)
r2_score(y_test, x_test_pred)
# Out:
# 0.7638974087055272

# %% [markdown]
# **XGBoost Regression Model**
# ---
#
#
#
# ---

# %%
from xgboost import XGBRegressor
from sklearn import metrics
model = XGBRegressor()
model.fit(x_train, y_train)
#Training data
training_data_prediction = model.predict(x_train)
#R square error
score_1 = metrics.r2_score(y_train , training_data_prediction)

#Mean absolute error
score_2 = metrics.mean_absolute_error(y_train, training_data_prediction)
print('R squared error: ', score_1)
print('Mean absolute error: ',score_2)
# Out:
# R squared error:  0.9985770148823054
# Mean absolute error:  0.06155404746576459

# %%
plt.scatter(y_train,training_data_prediction)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
#Testing data
test_data_prediction = model.predict(x_test)
# R squared error
score_1 = metrics.r2_score(y_test, test_data_prediction)

# Mean Absolute Error
score_2 = metrics.mean_absolute_error(y_test, test_data_prediction)

print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.9912155648062968
# Mean Absolute Error :  0.12888735384507516

# %%
plt.scatter(y_test,test_data_prediction)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
